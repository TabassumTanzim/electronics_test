# %%
# !pip install -Uqq fastai

# %%
from fastai.vision.all import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/MasterCourse/Electronics Recognizer
# Out:
# /content/drive/My Drive/MasterCourse/Electronics Recognizer

# %%
version = 4
img_path = 'test_images'
model_path = f'models/elec-recognizer-v{version}.pkl'

# %%
model=load_learner(model_path)

# %% [markdown]
# # Inference 1
# **Target:** Electric Fan

# %%
img = Image.open(f'{img_path}/unknown_00.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/unknown_00.jpg')
# Out:
# /usr/local/lib/python3.10/dist-packages/fastai/torch_core.py:263: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   return getattr(torch, 'has_mps', False)
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Fan appliances',
#  tensor(8),
#  tensor([1.1116e-04, 1.7822e-04, 5.0832e-07, 4.4691e-06, 5.0507e-05, 4.2019e-05,
# ...

# %% [markdown]
# # Inference 2
# Target: Hair Dryer

# %%
img = Image.open(f'{img_path}/unknown_01.jpg.webp')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=119x128>

# %%
model.predict(f'{img_path}/unknown_01.jpg.webp')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Hair dryer appliances',
#  tensor(10),
#  tensor([3.7893e-11, 2.6763e-10, 1.2194e-08, 8.4512e-12, 5.2645e-11, 3.8803e-12,
#          1.1970e-10, 1.2677e-08, 2.8376e-10, 5.6412e-11, 1.0000e+00, 3.0702e-10,
#          9.2596e-12, 3.7239e-09, 2.4639e-10, 2.3232e-11, 5.2831e-09, 8.4106e-11,
#          6.8608e-11, 4.1238e-09, 6.4274e-11, 3.5125e-09]))

# %% [markdown]
# # Inference 3
# **Target:** Electric Guitar

# %%
img = Image.open(f'{img_path}/unknown_02.webp')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=96x128>

# %%
model.predict(f'{img_path}/unknown_02.webp')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Electric Guitar appliances',
#  tensor(6),
#  tensor([1.0236e-07, 2.2656e-08, 8.7565e-10, 1.9664e-08, 2.0232e-10, 3.3780e-09,
#          1.0000e+00, 2.2854e-07, 6.2522e-07, 2.8173e-08, 1.0656e-07, 9.6283e-08,
#          4.2822e-09, 6.3840e-08, 1.1005e-09, 6.0196e-09, 1.0819e-08, 4.9092e-09,
#          5.5927e-09, 7.1599e-08, 4.5323e-09, 2.1547e-07]))

# %% [markdown]
# # Inference 4
# **Target:** Toaster

# %%
img=Image.open(f'{img_path}/unknown_03.jpeg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x87>

# %%
model.predict(f'{img_path}/unknown_03.jpeg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Toaster appliances',
#  tensor(20),
#  tensor([3.0200e-07, 2.7873e-07, 2.5659e-08, 1.0768e-07, 1.6081e-08, 8.6196e-09,
#          2.2965e-07, 4.8270e-09, 1.8057e-09, 3.1300e-07, 1.2119e-06, 1.3190e-08,
#          4.6533e-07, 2.6452e-07, 8.2297e-09, 5.7582e-07, 3.2441e-08, 1.3527e-09,
#          3.1596e-07, 4.1635e-09, 1.0000e+00, 1.2516e-08]))

# %% [markdown]
# # Inference 5
# **Target:** Heater

# %%
img=Image.open(f'{img_path}/unknown_04.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/unknown_04.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Heater appliances',
#  tensor(11),
#  tensor([6.8856e-05, 5.9043e-05, 7.3268e-08, 7.8425e-07, 4.7573e-06, 3.9289e-09,
#          1.1955e-06, 1.3806e-08, 2.1520e-04, 3.0465e-08, 5.7428e-07, 9.9961e-01,
#          2.6482e-08, 5.8018e-08, 8.4509e-06, 5.4620e-07, 4.1152e-08, 1.0358e-06,
#          3.4231e-07, 2.7768e-05, 1.5113e-06, 1.3226e-06]))
